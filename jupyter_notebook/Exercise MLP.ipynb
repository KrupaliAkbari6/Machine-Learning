# %% [markdown]
# # Exercise 1

# %% [markdown]
# # Load the dataset "housing-data.csv"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('housingdata.csv')
print(data)
    

# Load the dataset "housing-data.csv"

# plot the histograms for each feature

# create 2 variables called X and y: X shall be a matrix with 3 columns (sqft,bdrms,age) and y shall be a vector with 1 column (price)

# create a linear regression model with the appropriate number of inputs and output

# split the data into train and test with a 20% test size

# train the model on the training set and check its accuracy on training and test set

# how's your model doing? Is the loss growing smaller?

# try to improve your model with these experiments: normalize the input features with one of the rescaling techniques mentioned above

# once you're satisfied with training, check the accuracy on the test set
# Out:
#     sqft  bdrms  age   price
# 0   2104      3   70  399900
# 1   1600      3   28  329900
# 2   2400      3   44  369000
# 3   1416      2   49  232000
# 4   3000      4   75  539900
# 5   1985      4   61  299900
# 6   1534      3   12  314900
# 7   1427      3   57  198999
# 8   1380      3   14  212000
# 9   1494      3   15  242500
# 10  1940      4    7  239999
# 11  2000      3   27  347000
# 12  1890      3   45  329999
# 13  4478      5   49  699900
# 14  1268      3   58  259900
# 15  2300      4   77  449900
# 16  1320      2   62  299900
# 17  1236      3   78  199900
# 18  2609      4    5  499998
# 19  3031      4   21  599000
# 20  1767      3   44  252900
# 21  1888      2   79  255000
# 22  1604      3   13  242900
# 23  1962      4   53  259900
# 24  3890      3   36  573900
# 25  1100      3   60  249900
# 26  1458      3   29  464500
# 27  2526      3   13  469000
# 28  2200      3   28  475000
# 29  2637      3   25  299900
# 30  1839      2   40  349900
# ...

# %% [markdown]
# # plot the histograms for each feature ==>Preprosecing  Regression
#
# # create 2 variables called X and y: X shall be a matrix with 3 columns (sqft,bdrms,age) and y shall be a vector with 1 column (price)

# %% [markdown]
# # 1) SQRT v/s Price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model,model_selection
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix  #For classification
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error  #For regression

#load the data
data=pd.read_csv('housingdata.csv')
# print(data)

#split the dataset
x=np.array(data.sqft).reshape(-1,1)
y=np.array(data.price).reshape(-1,1)

#split the dataset in training and testing
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.2)

#load the model
#create a linear regression model with the appropriate number of inputs and output
lr=linear_model.LinearRegression()

#train the model : fit
lr.fit(xtrain,ytrain)

#test the model
ytest_result=lr.predict(xtest)
# print(xtest)
# print(ytest)
# print(ytest_result)

#visualize the actual value v/s predicted value
plt.scatter(xtest,ytest,color="red", label="Actual value")
plt.plot(xtest,ytest_result,color="blue", label="Pridicted value")
plt.xlabel("sqft")
plt.ylabel("Price")
plt.title("Predicted value of sqft")
plt.legend()
plt.show()

#Evaluation Matrix

print("mean absolute error : ",mean_absolute_error(ytest, ytest_result))
print("mean squared error : ",mean_squared_error(ytest, ytest_result))
print("mean absolute percentage error : ",mean_absolute_percentage_error(ytest, ytest_result))
# Out:
# mean absolute error :  72388.72935854382
# mean squared error :  7774749793.235786
# mean absolute percentage error :  0.21306963753757543

# %% [markdown]
# # 2) bdrms v/s Price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model,model_selection
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

#load the data
data=pd.read_csv('housingdata.csv')
# print(data)

#split the dataset
x=np.array(data.bdrms).reshape(-1,1)
y=np.array(data.price).reshape(-1,1)

#split the dataset in training and testing
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.2)

#load the model
lr=linear_model.LinearRegression()

#train the model : fit
lr.fit(xtrain,ytrain)

#test the model
# xtest=np.array([1.1,5.2,10.0]).reshape(-1,1)
ytest_result=lr.predict(xtest)
# print(xtest)
# print(ytest)
# print(ytest_result)

#visualize the actual value v/s predicted value
plt.scatter(xtest,ytest,color="red", label="Actual value")
plt.plot(xtest,ytest_result,color="blue", label="Pridicted value")
plt.xlabel("bdrms")
plt.ylabel("Price")
plt.title("Predicted value of bdrms")
plt.legend()
plt.show()

#Evaluation Matrix

print("mean absolute error : ",mean_absolute_error(ytest, ytest_result))
print("mean squared error : ",mean_squared_error(ytest, ytest_result))
print("mean absolute percentage error : ",mean_absolute_percentage_error(ytest, ytest_result))
# Out:
# mean absolute error :  91422.25590200444
# mean squared error :  17745318916.083862
# mean absolute percentage error :  0.19189209903575885

# %% [markdown]
# # 3) age v/s Price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model,model_selection
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

#load the data
data=pd.read_csv('housingdata.csv')
# print(data)

#split the dataset
x=np.array(data.age).reshape(-1,1)
y=np.array(data.price).reshape(-1,1)

#split the dataset in training and testing
xtrain,xtest,ytrain,ytest=model_selection.train_test_split(x,y,test_size=0.2)

#load the model
lr=linear_model.LinearRegression()

#train the model : fit
lr.fit(xtrain,ytrain)

#test the model
ytest_result=lr.predict(xtest)
# print(xtest)
# print(ytest)
# print(ytest_result)

#visualize the actual value v/s predicted value
plt.scatter(xtest,ytest,color="red", label="Actual value")
plt.plot(xtest,ytest_result,color="blue", label="Pridicted value")
plt.xlabel("age")
plt.ylabel("Price")
plt.title("Predicted value of age")
plt.legend()
plt.show()

#Evaluation Matrix

print("mean absolute error : ",mean_absolute_error(ytest, ytest_result))
print("mean squared error : ",mean_squared_error(ytest, ytest_result))
print("mean absolute percentage error : ",mean_absolute_percentage_error(ytest, ytest_result))
# Out:
# mean absolute error :  81102.04834526163
# mean squared error :  9014835511.30018
# mean absolute percentage error :  0.3088802863098957

# %% [markdown]
# # Exercise 2

# %%
# load the dataset at "HR_comma_sep.csv", inspect it with .head(), .info() and .describe().

# Check if any feature needs rescaling. You may plot the feature to decide which rescaling method is more appropriate.

# convert the categorical features into binary dummy columns. You will then have to combine them with the numerical features using pd.concat.

# do the usual train/test split with a 20% test size

# play around with learning rate and optimizer

# check the confusion matrix, precision and recall

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('HRcommasep.csv')
print(data)
print('-------------------------------------------------------------------------')

data.head(10)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# # Check if any feature needs rescaling. You may plot the feature to decide which rescaling method is more appropriate.

# %%
import numpy as np
from sklearn import preprocessing

df=pd.read_csv('HRcommasep.csv')
# print(data)

data=df[['satisfaction_level','last_evaluation','number_project','average_montly_hours','time_spend_company','Work_accident','left','promotion_last_5years']]
# print(data)

#Define a Scaller Model for scalling the data
scaller_model=preprocessing.MinMaxScaler()

#Apply data to model: fit
op1=scaller_model.fit(data)
# print(op1)

#let the model transfer the data according to requirement : transform
op2=op1.transform(data)

#print the reuslt
print(op2)
# Out:
# [[0.31868132 0.265625   0.         ... 0.         1.         0.        ]
#  [0.78021978 0.78125    0.6        ... 0.         1.         0.        ]
#  [0.02197802 0.8125     1.         ... 0.         1.         0.        ]
#  ...
#  [0.30769231 0.265625   0.         ... 0.         1.         0.        ]
#  [0.02197802 0.9375     0.8        ... 0.         1.         0.        ]
#  [0.30769231 0.25       0.         ... 0.         1.         0.        ]]

# %% [markdown]
# # convert the categorical features into binary dummy columns. You will then have to combine them with the numerical features using pd.concat.

# %%
import pandas as pd
from sklearn import preprocessing
df=pd.read_csv('HRcommasep.csv')

data=df[['sales']]
# op=preprocessing.normalize(data,norm='max')
# print(op)

labeled_data=preprocessing.LabelEncoder()
op=labeled_data.fit_transform(data)
print(data.head(50))
print(op)

cnt=pd.concat([df[data]])
# Out:
#          sales
# 0        sales
# 1        sales
# 2        sales
# 3        sales
# 4        sales
# 5        sales
# 6        sales
# 7        sales
# 8        sales
# 9        sales
# 10       sales
# 11       sales
# 12       sales
# 13       sales
# 14       sales
# 15       sales
# 16       sales
# 17       sales
# 18       sales
# 19       sales
# 20       sales
# 21       sales
# 22       sales
# 23       sales
# 24       sales
# 25       sales
# 26       sales
# 27       sales
# 28  accounting
# 29  accounting
# 30  accounting
# 31          hr
# 32          hr
# 33          hr
# 34          hr
# 35   technical
# 36   technical
# 37   technical
# 38   technical
# 39   technical
# 40   technical
# 41   technical
# 42   technical
# 43   technical
# 44   technical
# 45   technical
# 46     support
# 47     support
# 48     support
# 49     support
# [7 7 7 ... 8 8 8]
# ...

# %%
import pandas as pd
from sklearn import preprocessing
df=pd.read_csv('HRcommasep.csv')

data=df[['salary']]
# op=preprocessing.normalize(data,norm='max')
# print(op)

labeled_data=preprocessing.LabelEncoder()
op=labeled_data.fit_transform(data)
print(data.head(50))
print(op)
# Out:
#     salary
# 0      low
# 1   medium
# 2   medium
# 3      low
# 4      low
# 5      low
# 6      low
# 7      low
# 8      low
# 9      low
# 10     low
# 11     low
# 12     low
# 13     low
# 14     low
# 15     low
# 16     low
# 17     low
# 18     low
# 19     low
# 20     low
# 21     low
# 22     low
# 23     low
# 24     low
# 25     low
# 26     low
# 27     low
# 28     low
# 29     low
# 30     low
# 31     low
# 32     low
# 33     low
# 34     low
# 35     low
# 36     low
# 37     low
# 38     low
# 39     low
# 40     low
# 41     low
# 42     low
# 43     low
# 44     low
# 45     low
# 46     low
# 47     low
# 48     low
# 49     low
# [1 2 2 ... 1 1 1]
# C:\Users\MCA2\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
